# %%
row1 = [' ',' ', ' ', ' ', ' ',' ', ' ', ' ',' ']
from IPython.display import clear_output
def displaying_board(row1) :
    clear_output()
    print(row1[0] + '|' + row1[1] + '|' + row1[2])
    print(row1[3] + '|' + row1[4] + '|' + row1[5])
    print(row1[6] + '|' + row1[7] + '|' + row1[8])
def intro_to_game() :
    print('WELCOME TO THE TIC TAC TOE GAME ....')    
    print(f'OK lets start with the player 1 ')

def checking_space(choice) :
    if row1[choice-1]==' ' :
        return False
    else :
        print('the index is filled,please go for another...')
        return True
def choosing_symbol() :
    symbol = input("Player 1 plz choose either 'X' or 'O'")
    while symbol.upper() not in ['X','O']:
        symbol = input("player 1 plz choose either 'X ' or 'O' only...")
    if symbol.upper() == 'X' :
        return ('X' ,'O')
    else :
        return ('O','X')
def deciding_mark() :
    player1_mark ,player2_mark = choosing_symbol()
    game(player1_mark , player2_mark)
def game(player1_mark,player2_mark) :
    for num in range(1,10) :
        if num % 2 != 0 :
            check = True
            while check :
                print("it's chance for player 1 ")
                choice = int(input('enter your index : ')) 
                while choice not in range(1,10) :
                    choice = int(input('plz enter index in the range 1 to 9 only ..' ))
                check = checking_space(choice)
            row1[choice-1] = player1_mark
            marks = player1_mark
            displaying_board(row1)
            result = result_game(row1,marks)
            if result :
                break
        else :
            check = True
            while check :
                print("it's chance for player 2")
                choice = int(input('enter your index : '))
                while choice not in range(1,10) :
                    choice = int(input('plz enter index in the range 1 to 9 only ..' ))
                check = checking_space(choice)
            row1[choice-1] = player2_mark
            marks = player2_mark
            displaying_board(row1)
            result = result_game(row1,marks)
            if result :
                break
                             
def result_game(row1,marks):
    if row1[0]==row1[1]==row1[2]==marks :
        print(f'player with {marks} has won the game!!!')
        return True
    elif row1[3]==row1[4]==row1[5]==marks :
        print(f'player with {marks} has won the game!!!')
        return True
    elif row1[6]==row1[7]==row1[8]==marks :
        print(f'player with {marks} has won the game!!!')
        return True
    elif row1[0]==row1[1]==row1[2]==marks :
        print(f'player with {marks} has won the game!!!')
        return True
    elif row1[0]==row1[3]==row1[6]==marks :
        print(f'player with {marks} has won the game!!!')
        return True
    elif row1[1]==row1[4]==row1[7]==marks :
        print(f'player with {marks} has won the game!!!')
        return True
    elif row1[2]==row1[5]==row1[8]==marks :
        print(f'player with {marks} has won the game!!!')
        return True
    elif row1[0]==row1[4]==row1[8]==marks :
        print(f'player with {marks} has won the game!!')
        return True
    elif row1[2]==row1[4]==row1[6]==marks :
        print(f'player with {marks} has won the game!!!')
        return True
    elif row1[0]!= ' ' and row1[1]!=' 'and row1[2]!= ' ' and row1[3]!= ' ' and row1[4]!= ' ' and row1[5]!= ' ' and row1[6]!= ' ' and row1[7]!= ' ' and row1[8]!= ' ' :         
        print(f'The game has drwn!!!')
        return True
    else :
        pass

def sequence_steps() :    
    intro_to_game()
    deciding_mark()
sequence_steps()
choices = input('Do you want to continue (Y or N) : ')
while choices.upper() not in ['Y' ,'N'] :
    choices = input("please choose only either ,'Y' or 'N'")
if choices.upper() == 'Y' :
    row1 = [' ']*9
    sequence_steps()
else :
    pass
# Out:
# O|O|X
# X|X|O
# X|O|X
# player with X has won the game!!!
# Do you want to continue (Y or N) : n
